# %%
#dependencies
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "Resources/Births_and_Survival_by_Industry_Type_for_2012_to_2016.csv"

business_data = pd.read_csv(file)

business_data
# Out:
#         TABLE 4.2 - SURVIVAL OF NEWLY BORN ENTERPRISES Unnamed: 1  \
# 0                                                  NaN        NaN
# 1    BROAD INDUSTRY GROUP by BIRTHS AND THEIR SURVI...        NaN
# 2                                                  NaN        NaN
# 3                                                  NaN        NaN
# 4                                                  NaN        NaN
# 5                                                  NaN     Births
# 6                                                  NaN        NaN
# 7                                                 2012        NaN
# 8                                                  NaN        NaN
# 9                                           Production     14,245
# 10                                        Construction     29,215
# 11                                        Motor trades      6,325
# 12                                           Wholesale      9,895
# ...
