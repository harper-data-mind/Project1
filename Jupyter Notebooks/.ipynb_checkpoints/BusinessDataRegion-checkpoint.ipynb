# %%
#dependencies
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "../Resources/businessdemographyexceltablesthru2016.xlsx"
region_business_data_2016 = pd.read_excel(file,sheet_name="Table 5.1e")
region_business_data_2016 = region_business_data_2016.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_business_data_2016 = region_business_data_2016.iloc[:,0:2]
region_business_data_2016.dropna(how='any')
# Out:
#                                  Region  Births
# 6                        UNITED KINGDOM  413900
# 7                         GREAT BRITAIN  407965
# 8                     ENGLAND AND WALES  385695
# 9                               ENGLAND  373580
# 10                    NORTH EAST REGION   10180
# 11                    NORTH WEST REGION   42035
# 12      YORKSHIRE AND THE HUMBER REGION   26775
# 13                EAST MIDLANDS REGION    24630
# 14                 WEST MIDLANDS REGION   34695
# 15                          EAST REGION   45400
# 16                        LONDON REGION  102135
# 17                    SOUTH EAST REGION   55955
# 18                    SOUTH WEST REGION   31775
# 19                                WALES   12115
# 20                             SCOTLAND   22270
# 21                     NORTHERN IRELAND    5935

# %%
file = "../Resources/businessdemographyexceltablesthru2016.xlsx"
region_business_data_2015 = pd.read_excel(file,sheet_name="Table 5.1d")
region_business_data_2015 = region_business_data_2015.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_business_data_2015 = region_business_data_2015.iloc[:,0:2]
region_business_data_2015.dropna(how='any')
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  382755
# 1                         GREAT BRITAIN  377315
# 2                     ENGLAND AND WALES  355590
# 3                               ENGLAND  344065
# 4                     NORTH EAST REGION    9635
# 5                     NORTH WEST REGION   36500
# 6       YORKSHIRE AND THE HUMBER REGION   25140
# 7                 EAST MIDLANDS REGION    25345
# 8                  WEST MIDLANDS REGION   29350
# 9                           EAST REGION   35440
# 10                        LONDON REGION  100920
# 11                    SOUTH EAST REGION   55585
# 12                    SOUTH WEST REGION   26150
# 13                                WALES   11525
# 14                             SCOTLAND   21725
# 15                     NORTHERN IRELAND    5440

# %%
file = "../Resources/businessdemographyexceltablesthru2016.xlsx"
region_business_data_2014 = pd.read_excel(file,sheet_name="Table 5.1c")
region_business_data_2014 = region_business_data_2014.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_business_data_2014 = region_business_data_2014.iloc[:,0:2]
region_business_data_2014.dropna(how='any')
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  350305
# 1                         GREAT BRITAIN  345500
# 2                     ENGLAND AND WALES  324265
# 3                               ENGLAND  312920
# 4                     NORTH EAST REGION    9650
# 5                     NORTH WEST REGION   34275
# 6       YORKSHIRE AND THE HUMBER REGION   23465
# 7                 EAST MIDLANDS REGION    22035
# 8                  WEST MIDLANDS REGION   25740
# 9                           EAST REGION   32595
# 10                        LONDON REGION   88580
# 11                    SOUTH EAST REGION   51280
# 12                    SOUTH WEST REGION   25300
# 13                                WALES   11345
# 14                             SCOTLAND   21235
# 15                     NORTHERN IRELAND    4805

# %%
file = "../Resources/businessdemographyexceltablesthru2016.xlsx"
region_business_data_2013 = pd.read_excel(file,sheet_name="Table 5.1b")
region_business_data_2013 = region_business_data_2013.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_business_data_2013 = region_business_data_2013.iloc[:,0:2]
region_business_data_2013.dropna(how='any')
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  346275
# 1                         GREAT BRITAIN  341420
# 2                     ENGLAND AND WALES  319885
# 3                               ENGLAND  308565
# 4                     NORTH EAST REGION    9685
# 5                     NORTH WEST REGION   35285
# 6       YORKSHIRE AND THE HUMBER REGION   23120
# 7                 EAST MIDLANDS REGION    22035
# 8                  WEST MIDLANDS REGION   25735
# 9                           EAST REGION   32570
# 10                        LONDON REGION   83600
# 11                    SOUTH EAST REGION   50895
# 12                    SOUTH WEST REGION   25640
# 13                                WALES   11320
# 14                             SCOTLAND   21535
# 15                     NORTHERN IRELAND    4855

# %%
file = "../Resources/businessdemographyexceltablesthru2016.xlsx"
region_business_data_2012 = pd.read_excel(file,sheet_name="Table 5.1a")
region_business_data_2012 = region_business_data_2012.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_business_data_2012 = region_business_data_2012.iloc[:,0:2]
region_business_data_2012.dropna(how='any')
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  269250
# 1                         GREAT BRITAIN  265315
# 2                     ENGLAND AND WALES  247930
# 3                               ENGLAND  239660
# 4                     NORTH EAST REGION    7265
# 5                     NORTH WEST REGION   26535
# 6       YORKSHIRE AND THE HUMBER REGION   17680
# 7                 EAST MIDLANDS REGION    16625
# 8                  WEST MIDLANDS REGION   19645
# 9                           EAST REGION   25335
# 10                        LONDON REGION   65095
# 11                    SOUTH EAST REGION   41245
# 12                    SOUTH WEST REGION   20235
# 13                                WALES    8270
# 14                             SCOTLAND   17385
# 15                     NORTHERN IRELAND    3935

# %%
mid_file = "../Resources/businessdemographyexceltablesthru2013.xlsx"
region_mid_business_data_2011 = pd.read_excel(mid_file,sheet_name="Table 5.1c")
region_mid_business_data_2011 = region_mid_business_data_2011.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_mid_business_data_2011 = region_mid_business_data_2011.iloc[:,0:2]
region_mid_business_data_2011
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  261370
# 1                         GREAT BRITAIN  257625
# 2                     ENGLAND AND WALES  240685
# 3                               ENGLAND  232460
# 4                     NORTH EAST REGION    7070
# 5                     NORTH WEST REGION   25695
# 6       YORKSHIRE AND THE HUMBER REGION   17235
# 7                 EAST MIDLANDS REGION    16055
# 8                  WEST MIDLANDS REGION   19555
# 9                           EAST REGION   24930
# 10                        LONDON REGION   61395
# 11                    SOUTH EAST REGION   40775
# 12                    SOUTH WEST REGION   19750
# 13                                WALES    8225
# 14                             SCOTLAND   16940
# 15                     NORTHERN IRELAND    3745

# %%
mid_file = "../Resources/businessdemographyexceltablesthru2013.xlsx"
region_mid_business_data_2010 = pd.read_excel(mid_file,sheet_name="Table 5.1b")
region_mid_business_data_2010 = region_mid_business_data_2010.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_mid_business_data_2010 = region_mid_business_data_2010.iloc[:,0:2]
region_mid_business_data_2010
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  235145
# 1                         GREAT BRITAIN  230555
# 2                     ENGLAND AND WALES  215025
# 3                               ENGLAND  207520
# 4                     NORTH EAST REGION    5975
# 5                     NORTH WEST REGION   22705
# 6       YORKSHIRE AND THE HUMBER REGION   16630
# 7                 EAST MIDLANDS REGION    14325
# 8                  WEST MIDLANDS REGION   17805
# 9                           EAST REGION   22580
# 10                        LONDON REGION   52755
# 11                    SOUTH EAST REGION   36910
# 12                    SOUTH WEST REGION   17835
# 13                                WALES    7505
# 14                             SCOTLAND   15530
# 15                     NORTHERN IRELAND    4590

# %%
mid_file = "../Resources/businessdemographyexceltablesthru2013.xlsx"
region_mid_business_data_2009 = pd.read_excel(mid_file,sheet_name="Table 5.1a")
region_mid_business_data_2009 = region_mid_business_data_2009.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_mid_business_data_2009 = region_mid_business_data_2009.iloc[:,0:2]
region_mid_business_data_2009
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  236030
# 1                         GREAT BRITAIN  232085
# 2                     ENGLAND AND WALES  217360
# 3                               ENGLAND  209035
# 4                     NORTH EAST REGION    6625
# 5                     NORTH WEST REGION   23920
# 6       YORKSHIRE AND THE HUMBER REGION   17005
# 7                 EAST MIDLANDS REGION    14860
# 8                  WEST MIDLANDS REGION   18245
# 9                           EAST REGION   23535
# 10                        LONDON REGION   50575
# 11                    SOUTH EAST REGION   36320
# 12                    SOUTH WEST REGION   17950
# 13                                WALES    8325
# 14                             SCOTLAND   14725
# 15                     NORTHERN IRELAND    3945

# %%
mid_early_file = "../Resources/businessdemographyexceltablesthru2012.xlsx"
region_mid_business_data_2008 = pd.read_excel(mid_early_file,sheet_name="Table 5.1a")
region_mid_business_data_2008 = region_mid_business_data_2008.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_mid_business_data_2008 = region_mid_business_data_2008.iloc[:,0:2]
region_mid_business_data_2008
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  267445
# 1                         GREAT BRITAIN  261790
# 2                     ENGLAND AND WALES  245565
# 3                               ENGLAND  236345
# 4                     NORTH EAST REGION    7675
# 5                     NORTH WEST REGION   27465
# 6       YORKSHIRE AND THE HUMBER REGION   18675
# 7                 EAST MIDLANDS REGION    16785
# 8                  WEST MIDLANDS REGION   20585
# 9                           EAST REGION   25975
# 10                        LONDON REGION   57955
# 11                    SOUTH EAST REGION   40365
# 12                    SOUTH WEST REGION   20865
# 13                                WALES    9220
# 14                             SCOTLAND   16225
# 15                     NORTHERN IRELAND    5655

# %%
early_file = "../Resources/businessdemographythru2009.xlsx"
region_mid_business_data_2007 = pd.read_excel(early_file,sheet_name="Table 5.1c")
region_mid_business_data_2007 = region_mid_business_data_2007.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_mid_business_data_2007 = region_mid_business_data_2007.iloc[:,0:2]
region_mid_business_data_2007
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  280730
# 1                         GREAT BRITAIN  274770
# 2                     ENGLAND AND WALES  256605
# 3                               ENGLAND  246700
# 4                     NORTH EAST REGION    8795
# 5                     NORTH WEST REGION   30195
# 6       YORKSHIRE AND THE HUMBER REGION   20385
# 7                 EAST MIDLANDS REGION    18610
# 8                  WEST MIDLANDS REGION   22805
# 9                           EAST REGION   27600
# 10                        LONDON REGION   53120
# 11                    SOUTH EAST REGION   42320
# 12                    SOUTH WEST REGION   22870
# 13                                WALES    9905
# 14                             SCOTLAND   18165
# 15                     NORTHERN IRELAND    5960

# %%
early_file = "../Resources/businessdemographythru2009.xlsx"
region_mid_business_data_2006 = pd.read_excel(early_file,sheet_name="Table 5.1b")
region_mid_business_data_2006 = region_mid_business_data_2006.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_mid_business_data_2006 = region_mid_business_data_2006.iloc[:,0:2]
region_mid_business_data_2006
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  255530
# 1                         GREAT BRITAIN  249950
# 2                     ENGLAND AND WALES  234880
# 3                               ENGLAND  225120
# 4                     NORTH EAST REGION    7090
# 5                     NORTH WEST REGION   27265
# 6       YORKSHIRE AND THE HUMBER REGION   18555
# 7                 EAST MIDLANDS REGION    17715
# 8                  WEST MIDLANDS REGION   21025
# 9                           EAST REGION   25055
# 10                        LONDON REGION   47890
# 11                    SOUTH EAST REGION   39195
# 12                    SOUTH WEST REGION   21330
# 13                                WALES    9760
# 14                             SCOTLAND   15070
# 15                     NORTHERN IRELAND    5580

# %%
early_file = "../Resources/businessdemographythru2009.xlsx"
region_mid_business_data_2005 = pd.read_excel(early_file,sheet_name="Table 5.1a")
region_mid_business_data_2005 = region_mid_business_data_2005.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_mid_business_data_2005 = region_mid_business_data_2005.iloc[:,0:2]
region_mid_business_data_2005
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  274855
# 1                         GREAT BRITAIN  269220
# 2                     ENGLAND AND WALES  252285
# 3                               ENGLAND  241410
# 4                     NORTH EAST REGION    7655
# 5                     NORTH WEST REGION   29220
# 6       YORKSHIRE AND THE HUMBER REGION   19930
# 7                 EAST MIDLANDS REGION    19140
# 8                  WEST MIDLANDS REGION   23115
# 9                           EAST REGION   26195
# 10                        LONDON REGION   51285
# 11                    SOUTH EAST REGION   42555
# 12                    SOUTH WEST REGION   22315
# 13                                WALES   10875
# 14                             SCOTLAND   16935
# 15                     NORTHERN IRELAND    5635

# %%
earliest_file = "../Resources/businessdemography2004-2008.xlsx"
region_mid_business_data_2004 = pd.read_excel(earliest_file,sheet_name="Table 5.1a")
region_mid_business_data_2004 = region_mid_business_data_2004.rename(columns={"Unnamed: 0":"Region","Unnamed: 1":"Births",
                                             "Unnamed: 2":"1-Year Survival","Unnamed: 3":"1-Year Survival %",
                                              "Unnamed: 4":"2-Year Survival","Unnamed: 5":"2-Year Survival %",
                                             "Unnamed: 6":"3-Year Survival","Unnamed: 7":"3-Year Survival %",
                                              "Unnamed: 8":"4-Year Survival","Unnamed: 9":"4-Year Survival %",
                                              "Unnamed: 10":"5-Year Survival","Unnamed: 11":"5-Year Survival %"})
region_mid_business_data_2004 = region_mid_business_data_2004.iloc[:,0:2]
region_mid_business_data_2004
# Out:
#                                  Region  Births
# 0                        UNITED KINGDOM  280080
# 1                         GREAT BRITAIN  274350
# 2                     ENGLAND AND WALES  259975
# 3                               ENGLAND  248450
# 4                     NORTH EAST REGION    7645
# 5                     NORTH WEST REGION   28845
# 6       YORKSHIRE AND THE HUMBER REGION   20470
# 7                 EAST MIDLANDS REGION    18805
# 8                  WEST MIDLANDS REGION   23010
# 9                           EAST REGION   27600
# 10                        LONDON REGION   53620
# 11                    SOUTH EAST REGION   44345
# 12                    SOUTH WEST REGION   24110
# 13                                WALES   11525
# 14                             SCOTLAND   14375
# 15                     NORTHERN IRELAND    5730

# %%
#fix east midlands region discrepancy between excel files
a_business_region_data = pd.merge(region_mid_business_data_2004,region_mid_business_data_2005,on="Region",how="outer")
a_business_region_data = a_business_region_data.rename(columns={"Births_x":"2004","Births_y":"2005"})
ab_business_region_data = pd.merge(a_business_region_data,region_mid_business_data_2006,on="Region",how="outer")
ab_business_region_data = ab_business_region_data.rename(columns={"Births":"2006"})
abc_business_region_data = pd.merge(ab_business_region_data,region_mid_business_data_2007,on="Region",how="outer")
abc_business_region_data = abc_business_region_data.rename(columns={"Births":"2007"})
abcd_business_region_data = pd.merge(abc_business_region_data,region_mid_business_data_2008,on="Region",how="outer")
abcd_business_region_data = abcd_business_region_data.rename(columns={"Births":"2008"})
abcde_business_region_data = pd.merge(abcd_business_region_data,region_mid_business_data_2009,on="Region",how="outer")
abcde_business_region_data = abcde_business_region_data.rename(columns={"Births":"2009"})
abcdef_business_region_data = pd.merge(abcde_business_region_data,region_mid_business_data_2010,on="Region",how="outer")
abcdef_business_region_data = abcdef_business_region_data.rename(columns={"Births":"2010"})
abcdefg_business_region_data = pd.merge(abcdef_business_region_data,region_mid_business_data_2011,on="Region",how="outer")
abcdefg_business_region_data = abcdefg_business_region_data.rename(columns={"Births":"2011"})
abcdefgh_business_region_data = pd.merge(abcdefg_business_region_data,region_business_data_2012,on="Region",how="outer")
abcdefgh_business_region_data = abcdefgh_business_region_data.rename(columns={"Births":"2012"})
abcdefghi_business_region_data = pd.merge(abcdefgh_business_region_data,region_business_data_2013,on="Region",how="outer")
abcdefghi_business_region_data = abcdefghi_business_region_data.rename(columns={"Births":"2013"})
abcdefghij_business_region_data = pd.merge(abcdefghi_business_region_data,region_business_data_2014,on="Region",how="outer")
abcdefghij_business_region_data = abcdefghij_business_region_data.rename(columns={"Births":"2014"})
abcdefghijk_business_region_data = pd.merge(abcdefghij_business_region_data,region_business_data_2015,on="Region",how="outer")
abcdefghijk_business_region_data = abcdefghijk_business_region_data.rename(columns={"Births":"2015"})
region_business_data_all = pd.merge(abcdefghijk_business_region_data,region_business_data_2016,on="Region",how="outer")
region_business_data_all = region_business_data_all.rename(columns={"Births":"2016"})
region_business_data_all = region_business_data_all.drop([16,17,18,19,20,21])
# Out:
#                                  Region      2004      2005      2006  \
# 0                        UNITED KINGDOM  280080.0  274855.0  255530.0
# 1                         GREAT BRITAIN  274350.0  269220.0  249950.0
# 2                     ENGLAND AND WALES  259975.0  252285.0  234880.0
# 3                               ENGLAND  248450.0  241410.0  225120.0
# 4                     NORTH EAST REGION    7645.0    7655.0    7090.0
# 5                     NORTH WEST REGION   28845.0   29220.0   27265.0
# 6       YORKSHIRE AND THE HUMBER REGION   20470.0   19930.0   18555.0
# 7                 EAST MIDLANDS REGION    18805.0   19140.0   17715.0
# 8                  WEST MIDLANDS REGION   23010.0   23115.0   21025.0
# 9                           EAST REGION   27600.0   26195.0   25055.0
# 10                        LONDON REGION   53620.0   51285.0   47890.0
# 11                    SOUTH EAST REGION   44345.0   42555.0   39195.0
# 12                    SOUTH WEST REGION   24110.0   22315.0   21330.0
# 13                                WALES   11525.0   10875.0    9760.0
# 14                             SCOTLAND   14375.0   16935.0   15070.0
# 15                     NORTHERN IRELAND    5730.0    5635.0    5580.0
#
#         2007      2008      2009      2010      2011      2012      2013  \
# 0   280730.0  267445.0  236030.0  235145.0  261370.0  269250.0  346275.0
# 1   274770.0  261790.0  232085.0  230555.0  257625.0  265315.0  341420.0
# 2   256605.0  245565.0  217360.0  215025.0  240685.0  247930.0  319885.0
# 3   246700.0  236345.0  209035.0  207520.0  232460.0  239660.0  308565.0
# 4     8795.0    7675.0    6625.0    5975.0    7070.0    7265.0    9685.0
# 5    30195.0   27465.0   23920.0   22705.0   25695.0   26535.0   35285.0
# 6    20385.0   18675.0   17005.0   16630.0   17235.0   17680.0   23120.0
# 7    18610.0   16785.0   14860.0   14325.0   16055.0   16625.0   22035.0
# 8    22805.0   20585.0   18245.0   17805.0   19555.0   19645.0   25735.0
# 9    27600.0   25975.0   23535.0   22580.0   24930.0   25335.0   32570.0
# 10   53120.0   57955.0   50575.0   52755.0   61395.0   65095.0   83600.0
# 11   42320.0   40365.0   36320.0   36910.0   40775.0   41245.0   50895.0
# 12   22870.0   20865.0   17950.0   17835.0   19750.0   20235.0   25640.0
# 13    9905.0    9220.0    8325.0    7505.0    8225.0    8270.0   11320.0
# 14   18165.0   16225.0   14725.0   15530.0   16940.0   17385.0   21535.0
# 15    5960.0    5655.0    3945.0    4590.0    3745.0    3935.0    4855.0
#
#         2014      2015    2016
# 0   350305.0  382755.0  413900
# 1   345500.0  377315.0  407965
# 2   324265.0  355590.0  385695
# 3   312920.0  344065.0  373580
# 4     9650.0    9635.0   10180
# 5    34275.0   36500.0   42035
# 6    23465.0   25140.0   26775
# 7    22035.0   25345.0   24630
# 8    25740.0   29350.0   34695
# 9    32595.0   35440.0   45400
# 10   88580.0  100920.0  102135
# 11   51280.0   55585.0   55955
# 12   25300.0   26150.0   31775
# 13   11345.0   11525.0   12115
# 14   21235.0   21725.0   22270
# 15    4805.0    5440.0    5935

# %%
north_east_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[4]})
north_east_business_births.reset_index(level=0, inplace=True)
north_east_business_births = north_east_business_births.drop([0])
north_east_business_births
# Out:
#    index  Years
# 1   2004   7645
# 2   2005   7655
# 3   2006   7090
# 4   2007   8795
# 5   2008   7675
# 6   2009   6625
# 7   2010   5975
# 8   2011   7070
# 9   2012   7265
# 10  2013   9685
# 11  2014   9650
# 12  2015   9635
# 13  2016  10180

# %%
north_west_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[5]})
north_west_business_births.reset_index(level=0, inplace=True)
north_west_business_births = north_west_business_births.drop([0])
north_west_business_births
# Out:
#    index  Years
# 1   2004  28845
# 2   2005  29220
# 3   2006  27265
# 4   2007  30195
# 5   2008  27465
# 6   2009  23920
# 7   2010  22705
# 8   2011  25695
# 9   2012  26535
# 10  2013  35285
# 11  2014  34275
# 12  2015  36500
# 13  2016  42035

# %%
yorkshire_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[6]})
yorkshire_business_births.reset_index(level=0, inplace=True)
yorkshire_business_births = yorkshire_business_births.drop([0])
yorkshire_business_births
# Out:
#    index  Years
# 1   2004  20470
# 2   2005  19930
# 3   2006  18555
# 4   2007  20385
# 5   2008  18675
# 6   2009  17005
# 7   2010  16630
# 8   2011  17235
# 9   2012  17680
# 10  2013  23120
# 11  2014  23465
# 12  2015  25140
# 13  2016  26775

# %%
east_midlands_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[7]})
east_midlands_business_births.reset_index(level=0, inplace=True)
east_midlands_business_births = east_midlands_business_births.drop([0])
east_midlands_business_births
# Out:
#    index  Years
# 1   2004  18805
# 2   2005  19140
# 3   2006  17715
# 4   2007  18610
# 5   2008  16785
# 6   2009  14860
# 7   2010  14325
# 8   2011  16055
# 9   2012  16625
# 10  2013  22035
# 11  2014  22035
# 12  2015  25345
# 13  2016  24630

# %%
west_midlands_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[8]})
west_midlands_business_births.reset_index(level=0, inplace=True)
west_midlands_business_births = west_midlands_business_births.drop([0])
west_midlands_business_births
# Out:
#    index  Years
# 1   2004  23010
# 2   2005  23115
# 3   2006  21025
# 4   2007  22805
# 5   2008  20585
# 6   2009  18245
# 7   2010  17805
# 8   2011  19555
# 9   2012  19645
# 10  2013  25735
# 11  2014  25740
# 12  2015  29350
# 13  2016  34695

# %%
east_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[9]})
east_business_births.reset_index(level=0, inplace=True)
east_business_births = east_business_births.drop([0])
east_business_births
# Out:
#    index  Years
# 1   2004  27600
# 2   2005  26195
# 3   2006  25055
# 4   2007  27600
# 5   2008  25975
# 6   2009  23535
# 7   2010  22580
# 8   2011  24930
# 9   2012  25335
# 10  2013  32570
# 11  2014  32595
# 12  2015  35440
# 13  2016  45400

# %%
london_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[10]})
london_business_births.reset_index(level=0, inplace=True)
london_business_births = london_business_births.drop([0])
london_business_births
# Out:
#    index   Years
# 1   2004   53620
# 2   2005   51285
# 3   2006   47890
# 4   2007   53120
# 5   2008   57955
# 6   2009   50575
# 7   2010   52755
# 8   2011   61395
# 9   2012   65095
# 10  2013   83600
# 11  2014   88580
# 12  2015  100920
# 13  2016  102135

# %%
south_east_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[11]})
south_east_business_births.reset_index(level=0, inplace=True)
south_east_business_births = south_east_business_births.drop([0])
south_east_business_births
# Out:
#    index  Years
# 1   2004  44345
# 2   2005  42555
# 3   2006  39195
# 4   2007  42320
# 5   2008  40365
# 6   2009  36320
# 7   2010  36910
# 8   2011  40775
# 9   2012  41245
# 10  2013  50895
# 11  2014  51280
# 12  2015  55585
# 13  2016  55955

# %%
south_west_business_births = pd.DataFrame({"Years":region_business_data_all.iloc[12]})
south_west_business_births.reset_index(level=0, inplace=True)
south_west_business_births = south_west_business_births.drop([0])
south_west_business_births
# Out:
#    index  Years
# 1   2004  24110
# 2   2005  22315
# 3   2006  21330
# 4   2007  22870
# 5   2008  20865
# 6   2009  17950
# 7   2010  17835
# 8   2011  19750
# 9   2012  20235
# 10  2013  25640
# 11  2014  25300
# 12  2015  26150
# 13  2016  31775

# %%
plt.plot(north_east_business_births["index"],north_east_business_births["Years"],marker="o", label="North East")
plt.plot(north_west_business_births["index"],north_west_business_births["Years"],marker="o",label = "North West")
plt.plot(yorkshire_business_births["index"],yorkshire_business_births["Years"],marker="o", label = "Yorkshire")
plt.plot(east_midlands_business_births["index"],east_midlands_business_births["Years"],marker="o", label = "East Midlands")
plt.plot(west_midlands_business_births["index"],west_midlands_business_births["Years"],marker="o", label = "West Midlands")
plt.plot(east_business_births["index"],east_business_births["Years"],marker="o", label = "East")
plt.plot(london_business_births["index"],london_business_births["Years"],marker="o", label = "London")
plt.plot(south_east_business_births["index"],south_east_business_births["Years"],marker="o", label = "South East")
plt.plot(south_west_business_births["index"],south_west_business_births["Years"],marker="o", label = "South East")
plt.xticks(rotation=45)
plt.title("Business Births by Region per Year")
plt.xlabel("Year")
plt.ylabel("Total Business Births")
# Out:
# Text(0, 0.5, 'Total Business Births')
