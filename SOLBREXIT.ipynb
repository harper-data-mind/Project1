# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
jobsdensity_df = pd.read_csv(r"jobsdensity.csv")
unemployment_df = pd.read_csv(r"unemployment.csv")
weeklypaybyarea_df = pd.read_csv(r"weeklypaybyarea.csv")

# %%
jobsdensity_df.head()
# Out:
#        Job Density by Area  2004  2005  2006  2007  2008  2009  2010  2011  \
# 0  North East Lincolnshire  0.79  0.76  0.74  0.75  0.76  0.74  0.74  0.73
# 1                   Boston  0.77  0.84  0.80  0.85  0.77  0.75  0.82  0.84
# 2                Cambridge  1.07  1.04  1.12  1.14  1.17  1.15  1.07  1.08
# 3             Castle Point  0.43  0.45  0.45  0.51  0.45  0.47  0.48  0.48
# 4                  Lambeth  0.72  0.69  0.67  0.66  0.66  0.69  0.68  0.66
#
#    2012  2013  2014  2015  2016  2017
# 0  0.70  0.71  0.74  0.78  0.79  0.79
# 1  0.86  0.88  0.83  0.80  0.87  0.94
# 2  1.12  1.22  1.27  1.28  1.29  1.34
# 3  0.54  0.46  0.48  0.52  0.52  0.50
# 4  0.66  0.72  0.76  0.77  0.72  0.78

# %%
unemployment_df
# Out:
#   Unemployment Rate by Area  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0   North East Lincolnshire   6.0   6.3   6.6   7.5  10.5  10.9  12.3  11.5
# 1                    Boston   4.4   5.2   5.0   5.0   7.0   7.3   8.4   6.4
# 2                 Cambridge   4.8   5.4   5.3   5.0   4.8   5.2   5.4   4.7
# 3              Castle Point   3.4   4.0   3.6   4.3   6.9   6.8   7.0   7.3
# 4                   Lambeth   8.6   9.1   9.9   8.8  10.4   9.3  10.4  10.0
# 5                  Havering   4.8   4.8   3.9   5.0   7.9   8.5   8.2   9.4
# 6                    Oxford   4.8   5.9   6.5   5.3   5.7   6.6   5.7   5.9
# 7         City of Edinburgh   5.1   5.2   4.3   4.5   6.3   6.5   7.0   6.6
#
#    2013  2014  2015  2016  2017  2018
# 0  10.8   8.8   7.7   6.3   5.6   5.7
# 1   5.8   5.4   4.5   4.3   4.7   3.8
# 2   5.2   4.1   3.3   3.5   3.5   3.8
# 3   6.1   5.5   3.8   3.9   3.5   3.1
# 4   8.7   6.6   6.1   6.1   4.8   6.3
# 5   8.9   6.3   6.0   4.4   4.8   4.7
# 6   5.8   4.6   3.7   4.2   2.9   3.5
# 7   7.1   5.6   5.5   4.2   3.2   4.0

# %%
strongleave_df=weeklypaybyarea_df.loc[[0,1,3,5], :]
strongleave_df
# Out:
#   Gross Weekly Pay by Area ( Median)   2004   2005   2006   2007   2008  \
# 0            North East Lincolnshire  368.3  383.3  391.8  390.6  431.1
# 1                             Boston  338.9  357.0  376.6  397.5  373.2
# 3                       Castle Point  465.5  486.2  499.4  488.1  539.1
# 5                           Havering  518.2  541.6  525.0  549.5  606.6
#
#     2009   2010   2011   2012   2013   2014   2015   2016   2017   2018
# 0  451.7  429.3  482.6  460.1  466.4  468.6  450.4  469.9  447.9  497.0
# 1  369.5  396.0  365.3  399.2  411.1  430.7  411.0  411.2  410.2  421.6
# 3  529.1  465.2  519.2  512.1  537.2  568.1  550.0  555.7  632.4  607.6
# 5  576.7  593.8  582.3  584.3  594.1  615.4  624.7  622.9  631.0  642.0

# %%
strongleaveaverage_df=strongleave_df.mean()
strongleaveaverage_df=strongleaveaverage_df.to_frame().reset_index()
strongleaveaverage_df
# Out:
#    index        0
# 0   2004  422.725
# 1   2005  442.025
# 2   2006  448.200
# 3   2007  456.425
# 4   2008  487.500
# 5   2009  481.750
# 6   2010  471.075
# 7   2011  487.350
# 8   2012  488.925
# 9   2013  502.200
# 10  2014  520.700
# 11  2015  509.025
# 12  2016  514.925
# 13  2017  530.375
# 14  2018  542.050

# %%
strongstay_df=weeklypaybyarea_df.loc[[2,4,6,7], :]
strongstay_df
# Out:
#   Gross Weekly Pay by Area ( Median)   2004   2005   2006   2007   2008  \
# 2                          Cambridge  462.6  475.8  486.0  493.1  524.6
# 4                            Lambeth  491.4  509.6  508.0  538.7  553.0
# 6                             Oxford  435.7  451.8  466.3  483.6  498.2
# 7                  City of Edinburgh  428.2  460.2  479.7  498.8  507.2
#
#     2009   2010   2011   2012   2013   2014   2015   2016   2017   2018
# 2  547.9  556.4  574.4  617.7  572.3  575.6  583.3  589.1  595.6  642.4
# 4  598.3  647.0  632.4  625.8  629.6  628.3  616.5  616.2  666.1  689.9
# 6  495.6  514.9  526.5  517.9  533.1  571.8  556.8  589.1  631.6  623.8
# 7  514.3  523.6  525.4  537.7  562.0  562.6  555.3  559.7  583.8  575.9

# %%
strongstayaverage_df=strongstay_df.mean()
strongstayaverage_df=strongstayaverage_df.to_frame().reset_index()
strongstayaverage_df
# Out:
#    index        0
# 0   2004  454.475
# 1   2005  474.350
# 2   2006  485.000
# 3   2007  503.550
# 4   2008  520.750
# 5   2009  539.025
# 6   2010  560.475
# 7   2011  564.675
# 8   2012  574.775
# 9   2013  574.250
# 10  2014  584.575
# 11  2015  577.975
# 12  2016  588.525
# 13  2017  619.275
# 14  2018  633.000

# %%
weeklypaycomparison_df=pd.merge(strongstayaverage_df, strongleaveaverage_df, on='index', how='outer')
weeklypaycomparison_df
# Out:
#    index      0_x      0_y
# 0   2004  454.475  422.725
# 1   2005  474.350  442.025
# 2   2006  485.000  448.200
# 3   2007  503.550  456.425
# 4   2008  520.750  487.500
# 5   2009  539.025  481.750
# 6   2010  560.475  471.075
# 7   2011  564.675  487.350
# 8   2012  574.775  488.925
# 9   2013  574.250  502.200
# 10  2014  584.575  520.700
# 11  2015  577.975  509.025
# 12  2016  588.525  514.925
# 13  2017  619.275  530.375
# 14  2018  633.000  542.050

# %%
weeklypaycomparison_df= weeklypaycomparison_df.rename(columns={'index': 'Date', '0_x': 'Gross Weekly Pay in Strong Remain Counties', '0_y': 'Gross Weekly Pay in Strong Leave Counties'})
pd.set_option('display.precision', 2)

# %%
weeklypaycomparison_df
# Out:
#     Date  Gross Weekly Pay in Strong Remain Counties  \
# 0   2004                                      454.48
# 1   2005                                      474.35
# 2   2006                                      485.00
# 3   2007                                      503.55
# 4   2008                                      520.75
# 5   2009                                      539.02
# 6   2010                                      560.48
# 7   2011                                      564.67
# 8   2012                                      574.78
# 9   2013                                      574.25
# 10  2014                                      584.58
# 11  2015                                      577.97
# 12  2016                                      588.53
# 13  2017                                      619.28
# 14  2018                                      633.00
#
#     Gross Weekly Pay in Strong Leave Counties
# 0                                      422.73
# 1                                      442.02
# 2                                      448.20
# 3                                      456.43
# 4                                      487.50
# 5                                      481.75
# 6                                      471.07
# 7                                      487.35
# 8                                      488.93
# 9                                      502.20
# 10                                     520.70
# 11                                     509.03
# 12                                     514.92
# 13                                     530.38
# 14                                     542.05

# %%
weeklypaycomparison_df=weeklypaycomparison_df.set_index('Date')
weeklypaycomparison_df
# Out:
#       Gross Weekly Pay in Strong Remain Counties  \
# Date
# 2004                                      454.48
# 2005                                      474.35
# 2006                                      485.00
# 2007                                      503.55
# 2008                                      520.75
# 2009                                      539.02
# 2010                                      560.48
# 2011                                      564.67
# 2012                                      574.78
# 2013                                      574.25
# 2014                                      584.58
# 2015                                      577.97
# 2016                                      588.53
# 2017                                      619.28
# 2018                                      633.00
#
#       Gross Weekly Pay in Strong Leave Counties
# Date
# 2004                                     422.73
# 2005                                     442.02
# 2006                                     448.20
# 2007                                     456.43
# 2008                                     487.50
# 2009                                     481.75
# 2010                                     471.07
# 2011                                     487.35
# 2012                                     488.93
# 2013                                     502.20
# 2014                                     520.70
# 2015                                     509.03
# 2016                                     514.92
# 2017                                     530.38
# 2018                                     542.05

# %%
weeklypaycomparison_df.plot.line()
plt.title("Weekly Pay Comparison Between Strong Remain Counties and Strong Leave Counties")
plt.xlabel('Years')
plt.ylabel("Gross Weekly Pay in Pounds")
plt.tick_params(which='both', labelbottom=True, labelleft=True)
plt.xticks(np.arange(0, 15, step=1), np.arange(2004, 2019, step=1))
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
unemployment_df
# Out:
#   Unemployment Rate by Area  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0   North East Lincolnshire   6.0   6.3   6.6   7.5  10.5  10.9  12.3  11.5
# 1                    Boston   4.4   5.2   5.0   5.0   7.0   7.3   8.4   6.4
# 2                 Cambridge   4.8   5.4   5.3   5.0   4.8   5.2   5.4   4.7
# 3              Castle Point   3.4   4.0   3.6   4.3   6.9   6.8   7.0   7.3
# 4                   Lambeth   8.6   9.1   9.9   8.8  10.4   9.3  10.4  10.0
# 5                  Havering   4.8   4.8   3.9   5.0   7.9   8.5   8.2   9.4
# 6                    Oxford   4.8   5.9   6.5   5.3   5.7   6.6   5.7   5.9
# 7         City of Edinburgh   5.1   5.2   4.3   4.5   6.3   6.5   7.0   6.6
#
#    2013  2014  2015  2016  2017  2018
# 0  10.8   8.8   7.7   6.3   5.6   5.7
# 1   5.8   5.4   4.5   4.3   4.7   3.8
# 2   5.2   4.1   3.3   3.5   3.5   3.8
# 3   6.1   5.5   3.8   3.9   3.5   3.1
# 4   8.7   6.6   6.1   6.1   4.8   6.3
# 5   8.9   6.3   6.0   4.4   4.8   4.7
# 6   5.8   4.6   3.7   4.2   2.9   3.5
# 7   7.1   5.6   5.5   4.2   3.2   4.0

# %%
strongleaveunemployment_df=unemployment_df.loc[[0,1,3,5], :]
strongleaveunemployment_df
# Out:
#   Unemployment Rate by Area  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0   North East Lincolnshire   6.0   6.3   6.6   7.5  10.5  10.9  12.3  11.5
# 1                    Boston   4.4   5.2   5.0   5.0   7.0   7.3   8.4   6.4
# 3              Castle Point   3.4   4.0   3.6   4.3   6.9   6.8   7.0   7.3
# 5                  Havering   4.8   4.8   3.9   5.0   7.9   8.5   8.2   9.4
#
#    2013  2014  2015  2016  2017  2018
# 0  10.8   8.8   7.7   6.3   5.6   5.7
# 1   5.8   5.4   4.5   4.3   4.7   3.8
# 3   6.1   5.5   3.8   3.9   3.5   3.1
# 5   8.9   6.3   6.0   4.4   4.8   4.7

# %%
strongleaveavgunemployment_df=strongleaveunemployment_df.mean()
strongleaveavgunemployment_df=strongleaveavgunemployment_df.to_frame().reset_index()
strongleaveavgunemployment_df
# Out:
#    index     0
# 0   2005  4.65
# 1   2006  5.08
# 2   2007  4.77
# 3   2008  5.45
# 4   2009  8.07
# 5   2010  8.38
# 6   2011  8.98
# 7   2012  8.65
# 8   2013  7.90
# 9   2014  6.50
# 10  2015  5.50
# 11  2016  4.72
# 12  2017  4.65
# 13  2018  4.33

# %%
strongstayunemployment_df=unemployment_df.loc[[2,4,6,7], :]
strongstayunemployment_df
# Out:
#   Unemployment Rate by Area  2005  2006  2007  2008  2009  2010  2011  2012  \
# 2                 Cambridge   4.8   5.4   5.3   5.0   4.8   5.2   5.4   4.7
# 4                   Lambeth   8.6   9.1   9.9   8.8  10.4   9.3  10.4  10.0
# 6                    Oxford   4.8   5.9   6.5   5.3   5.7   6.6   5.7   5.9
# 7         City of Edinburgh   5.1   5.2   4.3   4.5   6.3   6.5   7.0   6.6
#
#    2013  2014  2015  2016  2017  2018
# 2   5.2   4.1   3.3   3.5   3.5   3.8
# 4   8.7   6.6   6.1   6.1   4.8   6.3
# 6   5.8   4.6   3.7   4.2   2.9   3.5
# 7   7.1   5.6   5.5   4.2   3.2   4.0

# %%
strongstayavgunemployment_df=strongstayunemployment_df.mean()
strongstayavgunemployment_df=strongstayavgunemployment_df.to_frame().reset_index()
strongstayavgunemployment_df
# Out:
#    index     0
# 0   2005  5.82
# 1   2006  6.40
# 2   2007  6.50
# 3   2008  5.90
# 4   2009  6.80
# 5   2010  6.90
# 6   2011  7.12
# 7   2012  6.80
# 8   2013  6.70
# 9   2014  5.22
# 10  2015  4.65
# 11  2016  4.50
# 12  2017  3.60
# 13  2018  4.40

# %%
unemploymentcomparison_df=pd.merge(strongstayavgunemployment_df, strongleaveavgunemployment_df, on='index', how='outer')
unemploymentcomparison_df
# Out:
#    index   0_x   0_y
# 0   2005  5.82  4.65
# 1   2006  6.40  5.08
# 2   2007  6.50  4.77
# 3   2008  5.90  5.45
# 4   2009  6.80  8.07
# 5   2010  6.90  8.38
# 6   2011  7.12  8.98
# 7   2012  6.80  8.65
# 8   2013  6.70  7.90
# 9   2014  5.22  6.50
# 10  2015  4.65  5.50
# 11  2016  4.50  4.72
# 12  2017  3.60  4.65
# 13  2018  4.40  4.33

# %%
unemploymentcomparison_df= unemploymentcomparison_df.rename(columns={'index': 'Date', '0_x': 'Unemployment Rate in Strong Remain Counties', '0_y': 'Unemployment Rate in Strong Leave Counties'})
pd.set_option('display.precision', 2)
unemploymentcomparison_df
# Out:
#     Date  Unemployment Rate in Strong Remain Counties  \
# 0   2005                                         5.82
# 1   2006                                         6.40
# 2   2007                                         6.50
# 3   2008                                         5.90
# 4   2009                                         6.80
# 5   2010                                         6.90
# 6   2011                                         7.12
# 7   2012                                         6.80
# 8   2013                                         6.70
# 9   2014                                         5.22
# 10  2015                                         4.65
# 11  2016                                         4.50
# 12  2017                                         3.60
# 13  2018                                         4.40
#
#     Unemployment Rate in Strong Leave Counties
# 0                                         4.65
# 1                                         5.08
# 2                                         4.77
# 3                                         5.45
# 4                                         8.07
# 5                                         8.38
# 6                                         8.98
# 7                                         8.65
# 8                                         7.90
# 9                                         6.50
# 10                                        5.50
# 11                                        4.72
# 12                                        4.65
# 13                                        4.33

# %%
unemploymentcomparison_df=unemploymentcomparison_df.set_index('Date')
unemploymentcomparison_df
# Out:
#       Unemployment Rate in Strong Remain Counties  \
# Date
# 2005                                         5.82
# 2006                                         6.40
# 2007                                         6.50
# 2008                                         5.90
# 2009                                         6.80
# 2010                                         6.90
# 2011                                         7.12
# 2012                                         6.80
# 2013                                         6.70
# 2014                                         5.22
# 2015                                         4.65
# 2016                                         4.50
# 2017                                         3.60
# 2018                                         4.40
#
#       Unemployment Rate in Strong Leave Counties
# Date
# 2005                                        4.65
# 2006                                        5.08
# 2007                                        4.77
# 2008                                        5.45
# 2009                                        8.07
# 2010                                        8.38
# 2011                                        8.98
# 2012                                        8.65
# 2013                                        7.90
# 2014                                        6.50
# 2015                                        5.50
# 2016                                        4.72
# 2017                                        4.65
# 2018                                        4.33

# %%
unemploymentcomparison_df.plot.line()
plt.title("Unemployment Rate in Strong Remain & Strong Leave Counties")
plt.xlabel('Years')
plt.ylabel("Unemployment Rate")
plt.tick_params(which='both', labelbottom=True, labelleft=True)
plt.xticks(np.arange(0, 14, step=1), np.arange(2005, 2019, step=1))
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
jobdensityleave_df=jobsdensity_df.loc[[0,1,3,5], :]
jobdensityleave_df
# Out:
#        Job Density by Area  2004  2005  2006  2007  2008  2009  2010  2011  \
# 0  North East Lincolnshire  0.79  0.76  0.74  0.75  0.76  0.74  0.74  0.73
# 1                   Boston  0.77  0.84  0.80  0.85  0.77  0.75  0.82  0.84
# 3             Castle Point  0.43  0.45  0.45  0.51  0.45  0.47  0.48  0.48
# 5                 Havering  0.65  0.63  0.60  0.56  0.59  0.54  0.55  0.55
#
#    2012  2013  2014  2015  2016  2017
# 0  0.70  0.71  0.74  0.78  0.79  0.79
# 1  0.86  0.88  0.83  0.80  0.87  0.94
# 3  0.54  0.46  0.48  0.52  0.52  0.50
# 5  0.56  0.60  0.59  0.60  0.61  0.64

# %%
avgjobdensityleave_df=jobdensityleave_df.mean()
avgjobdensityleave_df=avgjobdensityleave_df.to_frame().reset_index()
avgjobdensityleave_df
# Out:
#    index     0
# 0   2004  0.66
# 1   2005  0.67
# 2   2006  0.65
# 3   2007  0.67
# 4   2008  0.64
# 5   2009  0.62
# 6   2010  0.65
# 7   2011  0.65
# 8   2012  0.67
# 9   2013  0.66
# 10  2014  0.66
# 11  2015  0.68
# 12  2016  0.70
# 13  2017  0.72

# %%
jobdensitystay_df=jobsdensity_df.loc[[2,4,6,7], :]
jobdensitystay_df
# Out:
#   Job Density by Area  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# 2           Cambridge  1.07  1.04  1.12  1.14  1.17  1.15  1.07  1.08  1.12
# 4             Lambeth  0.72  0.69  0.67  0.66  0.66  0.69  0.68  0.66  0.66
# 6              Oxford  1.05  1.01  1.10  1.09  1.15  1.12  1.06  1.09  1.09
# 7   City of Edinburgh  1.13  1.12  1.08  1.06  1.05  1.05  1.01  1.04  1.07
#
#    2013  2014  2015  2016  2017
# 2  1.22  1.27  1.28  1.29  1.34
# 4  0.72  0.76  0.77  0.72  0.78
# 6  1.11  1.21  1.22  1.23  1.24
# 7  1.02  1.01  1.02  1.01  1.02

# %%
avgjobdensitystay_df=jobdensitystay_df.mean()
avgjobdensitystay_df=avgjobdensitystay_df.to_frame().reset_index()
avgjobdensitystay_df
# Out:
#    index     0
# 0   2004  0.99
# 1   2005  0.97
# 2   2006  0.99
# 3   2007  0.99
# 4   2008  1.01
# 5   2009  1.00
# 6   2010  0.96
# 7   2011  0.97
# 8   2012  0.99
# 9   2013  1.02
# 10  2014  1.06
# 11  2015  1.07
# 12  2016  1.06
# 13  2017  1.10

# %%
jobdensitycomparison_df=pd.merge(avgjobdensitystay_df, avgjobdensityleave_df, on='index', how='outer')
jobdensitycomparison_df
# Out:
#    index   0_x   0_y
# 0   2004  0.99  0.66
# 1   2005  0.97  0.67
# 2   2006  0.99  0.65
# 3   2007  0.99  0.67
# 4   2008  1.01  0.64
# 5   2009  1.00  0.62
# 6   2010  0.96  0.65
# 7   2011  0.97  0.65
# 8   2012  0.99  0.67
# 9   2013  1.02  0.66
# 10  2014  1.06  0.66
# 11  2015  1.07  0.68
# 12  2016  1.06  0.70
# 13  2017  1.10  0.72

# %%
jobdensitycomparison_df= jobdensitycomparison_df.rename(columns={'index': 'Date', '0_x': 'Job Density in Strong Remain Counties', '0_y': 'Job Density in Strong Leave Counties'})
pd.set_option('display.precision', 2)
jobdensitycomparison_df
# Out:
#     Date  Job Density in Strong Remain Counties  \
# 0   2004                                   0.99
# 1   2005                                   0.97
# 2   2006                                   0.99
# 3   2007                                   0.99
# 4   2008                                   1.01
# 5   2009                                   1.00
# 6   2010                                   0.96
# 7   2011                                   0.97
# 8   2012                                   0.99
# 9   2013                                   1.02
# 10  2014                                   1.06
# 11  2015                                   1.07
# 12  2016                                   1.06
# 13  2017                                   1.10
#
#     Job Density in Strong Leave Counties
# 0                                   0.66
# 1                                   0.67
# 2                                   0.65
# 3                                   0.67
# 4                                   0.64
# 5                                   0.62
# 6                                   0.65
# 7                                   0.65
# 8                                   0.67
# 9                                   0.66
# 10                                  0.66
# 11                                  0.68
# 12                                  0.70
# 13                                  0.72

# %%
jobdensitycomparison_df=jobdensitycomparison_df.set_index('Date')
jobdensitycomparison_df
# Out:
#       Job Density in Strong Remain Counties  \
# Date
# 2004                                   0.99
# 2005                                   0.97
# 2006                                   0.99
# 2007                                   0.99
# 2008                                   1.01
# 2009                                   1.00
# 2010                                   0.96
# 2011                                   0.97
# 2012                                   0.99
# 2013                                   1.02
# 2014                                   1.06
# 2015                                   1.07
# 2016                                   1.06
# 2017                                   1.10
#
#       Job Density in Strong Leave Counties
# Date
# 2004                                  0.66
# 2005                                  0.67
# 2006                                  0.65
# 2007                                  0.67
# 2008                                  0.64
# 2009                                  0.62
# 2010                                  0.65
# 2011                                  0.65
# 2012                                  0.67
# 2013                                  0.66
# 2014                                  0.66
# 2015                                  0.68
# 2016                                  0.70
# 2017                                  0.72

# %%
jobdensitycomparison_df.plot.line()
plt.title("Job Density in Strong Remain & Strong Leave Counties")
plt.xlabel('Years')
plt.ylabel("Job Density")
plt.xticks(np.arange(0, 14, step=1), np.arange(2004, 2018, step=1))
plt.xticks(rotation=45)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
